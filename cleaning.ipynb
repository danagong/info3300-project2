# %%
import pandas as pd
import numpy as np

# %%
trees = pd.read_csv("data/2015_Street_Tree_Census_-_Tree_Data.csv")
trees.head()
# Out:
#    tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status health  \
# 0   180683    348711  08/27/2015         3           0   OnCurb  Alive   Fair
# 1   200540    315986  09/03/2015        21           0   OnCurb  Alive   Fair
# 2   204026    218365  09/05/2015         3           0   OnCurb  Alive   Good
# 3   204337    217969  09/05/2015        10           0   OnCurb  Alive   Good
# 4   189565    223043  08/30/2015        21           0   OnCurb  Alive   Good
#
#                             spc_latin       spc_common  ...  boro_ct  \
# 0                         Acer rubrum        red maple  ...  4073900
# 1                   Quercus palustris          pin oak  ...  4097300
# 2  Gleditsia triacanthos var. inermis      honeylocust  ...  3044900
# 3  Gleditsia triacanthos var. inermis      honeylocust  ...  3044900
# 4                     Tilia americana  American linden  ...  3016500
#
#       state   latitude  longitude         x_sp         y_sp council district  \
# ...

# %%
trees.shape
# Out:
# (683788, 45)

# %%
trees['tree_dbh'].max()
# Out:
# 450

# %%
trees_alive = trees.loc[trees['status'] == 'Alive']
trees_alive = trees_alive.loc[trees['health'] == 'Good']
trees_alive = trees_alive.loc[trees['tree_dbh'] > 20]
trees_alive.head()
# Out:
#     tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status  \
# 4    189565    223043  08/30/2015        21           0   OnCurb  Alive
# 13   189465    219493  08/30/2015        22           0   OnCurb  Alive
# 26   192942    310298  08/31/2015        33           0   OnCurb  Alive
# 40   201494    406253  09/04/2015        24           0   OnCurb  Alive
# 44   193690    227528  09/01/2015        36           0   OnCurb  Alive
#
#    health              spc_latin        spc_common  ...  boro_ct     state  \
# 4    Good        Tilia americana   American linden  ...  3016500  New York
# 13   Good  Platanus x acerifolia  London planetree  ...  3019100  New York
# 26   Good  Platanus x acerifolia  London planetree  ...  4013800  New York
# 40   Good  Platanus x acerifolia  London planetree  ...  5012200  New York
# 44   Good  Platanus x acerifolia  London planetree  ...  3044000  New York
#
#      latitude  longitude          x_sp         y_sp council district  \
# ...

# %%
trees_alive=trees_alive.drop(columns=['address','community board','created_at','tree_dbh','steward',
                 'guards','stump_diam','curb_loc','state', 'cncldist','st_assem',
                 'st_senate','council district','bin','bbl','root_stone','root_grate',
                'root_other','trunk_wire','trnk_light','trnk_other','brch_light',
                'brch_shoe','brch_other','problems','user_type','sidewalk','spc_latin','postcode',
                         'zip_city','census tract','borocode','x_sp', 'y_sp','spc_common','status','health'])

trees_alive.head()
# Out:
#     tree_id  block_id        borough   nta                nta_name  boro_ct  \
# 4    189565    223043       Brooklyn  BK37      Park Slope-Gowanus  3016500
# 13   189465    219493       Brooklyn  BK69            Clinton Hill  3019100
# 26   192942    310298         Queens  QN60             Kew Gardens  4013800
# 40   201494    406253  Staten Island  SI45  New Dorp-Midland Beach  5012200
# 44   193690    227528       Brooklyn  BK46     Ocean Parkway South  3044000
#
#      latitude  longitude
# 4   40.666778 -73.975979
# 13  40.694733 -73.968211
# 26  40.706534 -73.824992
# 40  40.578074 -74.114746
# 44  40.613663 -73.974530

# %%
trees_alive.shape
# Out:
# (87474, 8)

# %%
trees_alive.to_csv('trees.csv')

# %%
trees_alive.groupby('borough')['tree_id'].count()
# Out:
# borough
# Bronx             80585
# Brooklyn         169744
# Manhattan         62427
# Queens           237974
# Staten Island    101443
# Name: tree_id, dtype: int64

# %%
zip_borough = pd.read_csv("nyc_zip_borough_neighborhoods_pop.csv")
zip_borough.head()
# Out:
#      zip    borough   post_office         neighborhood  population  density
# 0  10001  Manhattan  New York, NY  Chelsea and Clinton       21102    33959
# 1  10002  Manhattan  New York, NY      Lower East Side       81410    92573
# 2  10003  Manhattan  New York, NY      Lower East Side       56024    97188
# 3  10004  Manhattan  New York, NY      Lower Manhattan        3089     5519
# 4  10005  Manhattan  New York, NY      Lower Manhattan        7135    97048

# %%
air = pd.read_csv("Air_Quality.csv")
air.head()
# Out:
#    Unique ID  Indicator ID                  Name Measure Measure Info  \
# 0     216498           386            Ozone (O3)    Mean          ppb
# 1     216499           386            Ozone (O3)    Mean          ppb
# 2     219969           386            Ozone (O3)    Mean          ppb
# 3     219970           386            Ozone (O3)    Mean          ppb
# 4     164876           383  Sulfur Dioxide (SO2)    Mean          ppb
#
#   Geo Type Name  Geo Join ID                    Geo Place Name  \
# 0            CD          313               Coney Island (CD13)
# 1            CD          313               Coney Island (CD13)
# 2       Borough            1                             Bronx
# 3       Borough            1                             Bronx
# 4            CD          211  Morris Park and Bronxdale (CD11)
#
#       Time Period  Start_Date  Data Value  Message
# 0     Summer 2013  06/01/2013       34.64      NaN
# 1     Summer 2014  06/01/2014       33.22      NaN
# ...

# %%
air.tail()
# Out:
#        Unique ID  Indicator ID        Name Measure Measure Info Geo Type Name  \
# 16117     671118           386  Ozone (O3)    Mean          ppb            CD
# 16118     671119           386  Ozone (O3)    Mean          ppb            CD
# 16119     671120           386  Ozone (O3)    Mean          ppb            CD
# 16120     671121           386  Ozone (O3)    Mean          ppb            CD
# 16121     671122           386  Ozone (O3)    Mean          ppb            CD
#
#        Geo Join ID                          Geo Place Name  Time Period  \
# 16117          306    Park Slope and Carroll Gardens (CD6)  Summer 2020
# 16118          305   East New York and Starrett City (CD5)  Summer 2020
# 16119          304                          Bushwick (CD4)  Summer 2020
# 16120          303                Bedford Stuyvesant (CD3)  Summer 2020
# 16121          302  Fort Greene and Brooklyn Heights (CD2)  Summer 2020
#
#        Start_Date  Data Value  Message
# ...

# %%
air.shape
# Out:
# (16122, 12)

# %%
air['Name'].unique()
# Out:
# array(['Ozone (O3)', 'Sulfur Dioxide (SO2)', 'PM2.5-Attributable Deaths',
#        'Boiler Emissions- Total SO2 Emissions',
#        'Boiler Emissions- Total PM2.5 Emissions',
#        'Boiler Emissions- Total NOx Emissions',
#        'Air Toxics Concentrations- Average Benzene Concentrations',
#        'Air Toxics Concentrations- Average Formaldehyde Concentrations',
#        'PM2.5-Attributable Asthma Emergency Department Visits',
#        'PM2.5-Attributable Respiratory Hospitalizations (Adults 20 Yrs and Older)',
#        'PM2.5-Attributable Cardiovascular Hospitalizations (Adults 40 Yrs and Older)',
#        'Traffic Density- Annual Vehicle Miles Traveled',
#        'O3-Attributable Cardiac and Respiratory Deaths',
#        'O3-Attributable Asthma Emergency Department Visits',
#        'O3-Attributable Asthma Hospitalizations',
#        'Traffic Density- Annual Vehicle Miles Traveled for Cars',
#        'Traffic Density- Annual Vehicle Miles Traveled for Trucks',
# ...

# %%
particulates = air.loc[air['Name'] == 'Fine Particulate Matter (PM2.5)']
particulates.head()
# Out:
#       Unique ID  Indicator ID                             Name Measure  \
# 2709     168394           365  Fine Particulate Matter (PM2.5)    Mean
# 2710     168395           365  Fine Particulate Matter (PM2.5)    Mean
# 2711     168396           365  Fine Particulate Matter (PM2.5)    Mean
# 2712     168397           365  Fine Particulate Matter (PM2.5)    Mean
# 2713     168398           365  Fine Particulate Matter (PM2.5)    Mean
#
#              Measure Info Geo Type Name  Geo Join ID  \
# 2709  mcg per cubic meter            CD          101
# 2710  mcg per cubic meter            CD          102
# 2711  mcg per cubic meter            CD          103
# 2712  mcg per cubic meter            CD          104
# 2713  mcg per cubic meter            CD          105
#
#                            Geo Place Name     Time Period  Start_Date  \
# 2709             Financial District (CD1)  Winter 2008-09  12/01/2008
# 2710     Greenwich Village and Soho (CD2)  Winter 2008-09  12/01/2008
# ...

# %%
particulates.shape
# Out:
# (5076, 12)

# %%
particulates['Geo Place Name']
# Out:
# 2709                Financial District (CD1)
# 2710        Greenwich Village and Soho (CD2)
# 2711     Lower East Side and Chinatown (CD3)
# 2712               Clinton and Chelsea (CD4)
# 2713                           Midtown (CD5)
#                         ...
# 15978      South Beach and Willowbrook (CD2)
# 15979      South Beach and Willowbrook (CD2)
# 15980      Tottenville and Great Kills (CD3)
# 15981      Tottenville and Great Kills (CD3)
# 15982      Tottenville and Great Kills (CD3)
# Name: Geo Place Name, Length: 5076, dtype: object

# %%
particulates['Geo Type Name'].unique()
particulates = particulates.loc[particulates['Geo Type Name'] == 'CD']
particulates.head()
# Out:
#       Unique ID  Indicator ID                             Name Measure  \
# 2709     168394           365  Fine Particulate Matter (PM2.5)    Mean
# 2710     168395           365  Fine Particulate Matter (PM2.5)    Mean
# 2711     168396           365  Fine Particulate Matter (PM2.5)    Mean
# 2712     168397           365  Fine Particulate Matter (PM2.5)    Mean
# 2713     168398           365  Fine Particulate Matter (PM2.5)    Mean
#
#              Measure Info Geo Type Name  Geo Join ID  \
# 2709  mcg per cubic meter            CD          101
# 2710  mcg per cubic meter            CD          102
# 2711  mcg per cubic meter            CD          103
# 2712  mcg per cubic meter            CD          104
# 2713  mcg per cubic meter            CD          105
#
#                            Geo Place Name     Time Period  Start_Date  \
# 2709             Financial District (CD1)  Winter 2008-09  12/01/2008
# 2710     Greenwich Village and Soho (CD2)  Winter 2008-09  12/01/2008
# ...

# %%
particulates.shape
# Out:
# (2124, 12)

# %%
particulates['Geo Join ID']
# Out:
# 2709     101
# 2710     102
# 2711     103
# 2712     104
# 2713     105
#         ...
# 15978    502
# 15979    502
# 15980    503
# 15981    503
# 15982    503
# Name: Geo Join ID, Length: 2124, dtype: int64

# %%
particulates = particulates.groupby('Geo Join ID')['Data Value'].mean().reset_index()
particulates = particulates.rename(columns={'Geo Join ID': 'community_district', 'Data Value': 'particle_concentration'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/7c/45yp5pl95_14d1f8zd27k9wr0000gn/T/ipykernel_37688/1026775982.py in <module>
# ----> 1 particulates = particulates.groupby('Geo Join ID')['Data Value'].mean().reset_index()
#       2 particulates = particulates.rename(columns={'Geo Join ID': 'community_district', 'Data Value': 'particle_concentration'})
#       3 particulates
#
# ~/miniconda3/envs/3350/lib/python3.9/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7629         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7630         # "Union[bool, NoDefault]"; expected "bool"
# -> 7631         return DataFrameGroupBy(
#    7632             obj=self,
#    7633             keys=by,
#
# ...

# %%
particulates.to_csv('air.csv')

# %%
test.shape
# Out:
# (59,)

# %%
particulates
# Out:
#     community_district  particle_concentration
# 0                  101               11.166667
# 1                  102               11.267500
# 2                  103               10.374722
# 3                  104               11.445556
# 4                  105               13.651111
# 5                  106               11.954444
# 6                  107               10.277500
# 7                  108               10.893056
# 8                  109                9.914444
# 9                  110                9.828611
# 10                 111                9.890556
# 11                 112                9.825833
# 12                 201               10.288333
# 13                 202               10.224444
# 14                 203                9.753333
# 15                 204               10.179444
# 16                 205               10.268889
# 17                 206                9.842222
# 18                 207                9.710833
# ...
